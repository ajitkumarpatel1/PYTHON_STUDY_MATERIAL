# %% [markdown]
# # 1. Variables
#
# * Variable is an entity or a reserve memory loacation where we can store the value like numeric, textual, boolean etc and retrive it latter.
# * variable in a python program gives data to the computer for processing.
# * The type of data contained in a variable can be changed at user's will.
#
#
# * Mainly two types of variables are present
#  1.   Static variable
#  2.   Dynamic variable
#
#
#
#
#           1)Static variable  -- another programing language follow
#               a)static Typing --> user need to declair the data tyes of data to stor in a variable   example: int a = 5
#               b)Static Binding --> One variable can store only one data types
#
#           2)Dynamic variable -- Python/PHP follow
#               a)Dynamic Typing --> No need to declair the daya types,python automatically detect  example: a = 5
#               b)Dynamic Binding -->One variable can store multiple data types.
#                                   example: a = 5
#                                            print(a)
#                                            a = 'data science'
#                                            print(a)

# %%
# Static Vs Dynamic Typing
# Static Vs Dynamic Binding
# stylish declaration techniques

# %%
## varible to store string data types
name = 'Data science'
print(name)


## varible to store integer data types
a = 5
b = 6
print(a + b)
# Out:
# Data science
# 11

# %% [markdown]
# ###  stylish declaration techniques

# %%
a = 1
b = 2
c = 3
print(a,b,c)
# Out:
# 1 2 3

# %%
a,b,c = 1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
a=b=c= 5
print(a,b,c)
# Out:
# 5 5 5

# %% [markdown]
# # b)Identifiers:
# * A python identifiers is a nmae used to identify the variable, function, class, module or other object.
#
# ### Rules for naming identifiers:
# * A identifiers must be start with a alphabet(a-z or A-Z) or '_' .
# * A identifiers can't contain any white spaces or any special character use '_' instade.
# * Reserved keyword can not be use as identifiers.

# %%
# Identifiers
# You can't start with a digit
name1 = 'Data Science'
print(name1)
# You can use special chars -> _
_ = 'Dream of ever one'
print(_)
# identiers can not be keyword
# Out:
# Data Science
# Dream of ever one
