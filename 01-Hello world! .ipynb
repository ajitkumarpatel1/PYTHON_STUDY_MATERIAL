# %% [markdown]
# # 1.Print function:
# * Print is a usefull function in python is helps us to print anything as per our requirements
# * its take 4 hyperparameter
#
#
#
# 1.   sep - its seperate every element (defult = " " space)
# 2.   end - its handle the end of statement (defult = "\n" newline)
# 3.   file -
# 4.   flush -  this two are use full for file handling

# %%
# Python is a case sensitive language
print('Hello World')
# Out:
# Hello World

# %%
print('Data science',"machine learning")
# Out:
# Data science machine learning

# %%
print(salman khan)
# Out:
#   File "<ipython-input-3-0713073d8d88>", line 1
#     print(salman khan)
#                  ^
# SyntaxError: invalid syntax

# %%
## printing integer data types
print(7)
# Out:
# 7

# %%
# printing floating point data types
print(7.7)
# Out:
# 7.7

# %%
# printing Boolean data types
print(True)
# Out:
# True

# %%
## printing any hetrogenious data types
print('Hello',1,4.5,True)
# Out:
# Hello 1 4.5 True

# %% [markdown]
# ### 'sep' parameter in string:
# * by defult sep =" " but if user want the they change it also.

# %%
print('Hello',1,4.5,True,sep='/')
# Out:
# Hello/1/4.5/True

# %% [markdown]
# ### 'end' parameter in string:
# * by defult end ="\n" but if user want the they change it also.
# * its helps us to mange the line

# %%
# with out end the out put
print('hello')
print('world')
# Out:
# hello
# world

# %%
# with line the output
print('hello',end='-')
print('world')
# Out:
# hello-world
