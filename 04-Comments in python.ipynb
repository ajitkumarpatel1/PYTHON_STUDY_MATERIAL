# %% [markdown]
# # Comments:
# * Comment is a pic of code which is not excutated by the enterperter or Compiler.
# * It enhance the code readablity.
# * There are three tyes of comments are present in python:
#
#
# 1.   Single line comment: use #
# 2.   Multi line comment : use """ """
# 3.   Doctype string comment : It use in side a function to describe the functionality of code.

# %%
# This is a SINGLE LINE COMMENT



'''
This is a MULTI LINE COMMENT
it is help full for write more
then one line of comment 
'''

def example():
    """
    *****************************************************************************
    *
    * filename:       Comments.py
    * version:        1.0
    * author:         AJIT KUMAR PATEL
    * creation date:  03-DEC-2022
    *
    * change history:
    *
    * who             when           version  change (include bug# if apply)
    * ----------      -----------    -------  ------------------------------
    * AJIT KUMAR      03-NOV-2022    1.0      initial creation
    *
    *
    * description:    This is the example for Doctype string
    *
    ****************************************************************************
    """
    pass
